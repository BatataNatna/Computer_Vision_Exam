# %% [markdown]
# # Eercice 1
#
# Nom: MERAD
#
# Prénom: Khedoudja Rym
#
# Groupe: M2 Data Science
#
# Campus: E-Learning

# %% [markdown]
# ## Import des bibliothèques

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Réponses

# %% [markdown]
# **1-Création du réseau à une couhe**

# %%
model = Sequential()
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# **2-Generer les données Keras**

# %%
# Entraîner le modèle
# Générer un ensemble de données synthétiques avec make_moons
X, y = make_moons(n_samples=1000, noise=0.2, random_state=42)

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardiser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7318 - val_loss: 0.5728
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6976 - val_loss: 0.5298
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6155 - val_loss: 0.4909
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6004 - val_loss: 0.4545
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5289 - val_loss: 0.4207
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4895 - val_loss: 0.3893
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4740 - val_loss: 0.3598
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4408 - val_loss: 0.3326
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4235 - val_loss: 0.3077
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3858 - val_loss: 0.2855
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3407 - val_loss: 0.2649
# Epoch 12/100
# ...

# %% [markdown]
# **Entrainement du Model**

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0968 - val_loss: 0.0838
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1032 - val_loss: 0.0839
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1054 - val_loss: 0.0839
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1017 - val_loss: 0.0839
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0988 - val_loss: 0.0839
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1058 - val_loss: 0.0839
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1031 - val_loss: 0.0839
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0959 - val_loss: 0.0839
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1007 - val_loss: 0.0839
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1055 - val_loss: 0.0839
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1099 - val_loss: 0.0839
# Epoch 12/100
# ...

# %% [markdown]
# **4-Evaluer les performances**

# %%
# Évaluer le modèle sur les données de test
y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on test data: {accuracy:.2f}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy on test data: 0.87

# %% [markdown]
# **L'accuracy est de 89%**

# %% [markdown]
# **6-Visualisation**

# %%
# Définir une fonction pour tracer la frontière de décision
def plot_decision_boundary(model, X, y):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
    grid = np.c_[xx.ravel(), yy.ravel()]
    probs = model.predict(grid).reshape(xx.shape)
    
    plt.contourf(xx, yy, probs, levels=[0, 0.5, 1], cmap="RdBu", alpha=0.6)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap="RdBu", edgecolor="white", marker="o")
    plt.grid()
    plt.show()

# Tracer la frontière de décision
plot_decision_boundary(model, X_test, y_test)
# Out:
# 12961/12961 ━━━━━━━━━━━━━━━━━━━━ 12s 890us/step

# %% [markdown]
# **On remarque qu'il y aparfois quelques elements bleus dans la zone rose qui a été mal reconnuue mais à part ça le modèle a de bonnes performances**
